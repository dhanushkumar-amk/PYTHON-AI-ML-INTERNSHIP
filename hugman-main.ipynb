# %% [markdown]
# ### **Import & Word List**

# %%
import random

WORD_LIST = [
    "python",
    "hangman",
    "computer",
    "programming",
    "keyboard",
    "science",
    "elephant",
    "mountain"
]

# %% [markdown]
# ### **Hangman Stages**

# %%
HANGMAN_STAGES = [
    """
  -----
  |   |
      |
      |
      |
      |
=========
    """,
    """
  -----
  |   |
  O   |
      |
      |
      |
=========
    """,
    """
  -----
  |   |
  O   |
  |   |
      |
      |
=========
    """,
    """
  -----
  |   |
  O   |
 /|   |
      |
      |
=========
    """,
    """
  -----
  |   |
  O   |
 /|\\  |
      |
      |
=========
    """,
    """
  -----
  |   |
  O   |
 /|\\  |
 /    |
      |
=========
    """,
    """
  -----
  |   |
  O   |
 /|\\  |
 / \\  |
      |
=========
    """
]

# %% [markdown]
# ### **Display Word Function**

# %%
def display_word(word, guessed_letters):
    display = ""

    for letter in word:
        if letter in guessed_letters:
            display += letter + " "
        else:
            display += "_ "

    return display.strip()

# %% [markdown]
# ### **Check Win Function**

# %%
def check_win(word, guessed_letters):

    for letter in word:
        if letter not in guessed_letters:
            return False

    return True

# %% [markdown]
# ### **Main Game Function**

# %%
def play_hangman():

    print("=" * 40)
    print("      Welcome to HANGMAN GAME!")
    print("=" * 40)

    word = random.choice(WORD_LIST)

    guessed_letters = []

    wrong_guesses = 0
    max_wrong = 6

    print(f"\nThe word has {len(word)} letters. Good luck!\n")

    while wrong_guesses < max_wrong:

        print(HANGMAN_STAGES[wrong_guesses])

        print(f"Word: {display_word(word, guessed_letters)}")

        if guessed_letters:
            print(f"Guessed letters: {', '.join(sorted(guessed_letters))}")
        else:
            print("Guessed letters: None")

        print(f"Attempts left: {max_wrong - wrong_guesses}")

        guess = input("Enter a letter: ").lower().strip()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single alphabet letter only!\n")
            continue

        if guess in guessed_letters:
            print(f"You already guessed '{guess}'!\n")
            continue

        guessed_letters.append(guess)

        if guess in word:
            print(f"Good guess! '{guess}' is in the word!\n")
        else:
            wrong_guesses += 1
            print(f"Wrong guess! '{guess}' is NOT in the word.\n")

        if check_win(word, guessed_letters):

            print(HANGMAN_STAGES[wrong_guesses])

            print(f"Word: {display_word(word, guessed_letters)}")

            print("\nCongratulations! You WON!")
            print(f"The word was: '{word}'")

            return

    print(HANGMAN_STAGES[wrong_guesses])

    print("\nGAME OVER! You lost.")
    print(f"The word was: '{word}'")

# %% [markdown]
# ### **Replay Function**

# %%
def main():

    while True:

        play_hangman()

        again = input(
            "\nDo you want to play again? (yes/no): "
        ).lower().strip()

        if again not in ["yes", "y"]:
            print("Thanks for playing! Goodbye!")
            break

# %% [markdown]
# ### **Run the Program**

# %%
if __name__ == "__main__":
    main()
# Out:
# ========================================
#       Welcome to HANGMAN GAME!
# ========================================
#
# The word has 8 letters. Good luck!
#
#
#   -----
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# Word: _ _ _ _ _ _ _ _
# Guessed letters: None
# Attempts left: 6
# Wrong guess! 'h' is NOT in the word.
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: _ _ _ _ _ _ _ _
# Guessed letters: h
# Attempts left: 5
# Good guess! 'c' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c _ _ _ _ _ _ _
# Guessed letters: c, h
# Attempts left: 5
# Good guess! 'o' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o _ _ _ _ _ _
# Guessed letters: c, h, o
# Attempts left: 5
# You already guessed 'o'!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o _ _ _ _ _ _
# Guessed letters: c, h, o
# Attempts left: 5
# Good guess! 'm' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o m _ _ _ _ _
# Guessed letters: c, h, m, o
# Attempts left: 5
# Good guess! 'p' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o m p _ _ _ _
# Guessed letters: c, h, m, o, p
# Attempts left: 5
# Good guess! 'u' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o m p u _ _ _
# Guessed letters: c, h, m, o, p, u
# Attempts left: 5
# Good guess! 't' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o m p u t _ _
# Guessed letters: c, h, m, o, p, t, u
# Attempts left: 5
# You already guessed 't'!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o m p u t _ _
# Guessed letters: c, h, m, o, p, t, u
# Attempts left: 5
# Good guess! 'e' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o m p u t e _
# Guessed letters: c, e, h, m, o, p, t, u
# Attempts left: 5
# Good guess! 'r' is in the word!
#
#
#   -----
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Word: c o m p u t e r
#
# Congratulations! You WON!
# The word was: 'computer'
# Thanks for playing! Goodbye!
